# %% [markdown]
# # Introduction.
#
# Hello community, I want to break the bad streak and finally give the world my first Kaggle notebook. I'm so excited because this project looks kind of odd, and I want to apply it to my daily life since I spend 8-12 hours using the internet.

# %% [markdown]
# # Index
#
# **0. Import functionalities.**
#
#    1. Import native libraries.
#    2. Useful functions.
#
# **1. Import data.**
#
#    1. Data dictionary.
#    2. Sample submission.
#    3. Train data.
#    4. Test data.
#    5. Rename data to understanding.
#
#
# **2. Understanding "sii"**
#
#    1. Brief description of "sii" (by the competition data).
#    2. Preselect some variables.
#    3. Graphs of "sii".
#    4. Conclusion.
#
# **3. Feature Engineering.**
#
#    1. Data cleansing.
#
# **4. Machine learning.**
#
#    1. Supervised learning models.
#    2. [Section to be completed]
#
# **5. Prediction.**
#
# **6. Conclusion.**

# %% [markdown]
# # 0. Import functionalities.

# %% [markdown]
# ## 0.1 Import native libraries.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ## 0.2 Preconstructed useful functions.

# %% [markdown]
# # 1. Import data.

# %% [markdown]
# ## 1.1 Data dictionary.

# %%
dictionary = pd.read_csv("/kaggle/input/child-mind-institute-problematic-internet-use/data_dictionary.csv")
dictionary.head()
# Out:
#                            Instrument                      Field  \
# 0                          Identifier                         id
# 1                        Demographics  Basic_Demos-Enroll_Season
# 2                        Demographics            Basic_Demos-Age
# 3                        Demographics            Basic_Demos-Sex
# 4  Children's Global Assessment Scale                CGAS-Season
#
#                Description             Type                        Values  \
# 0         Participant's ID              str                           NaN
# 1     Season of enrollment              str  Spring, Summer, Fall, Winter
# 2       Age of participant            float                           NaN
# 3       Sex of participant  categorical int                           0,1
# 4  Season of participation              str  Spring, Summer, Fall, Winter
#
#        Value Labels
# 0               NaN
# 1               NaN
# 2               NaN
# 3  0=Male, 1=Female
# 4               NaN

# %% [markdown]
# # 1.2 Sample Submission.

# %%
Sample_Submission = pd.read_csv("/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv")
Sample_Submission.head()
# Out:
#          id  sii
# 0  00008ff9    0
# 1  000fd460    1
# 2  00105258    2
# 3  00115b9f    3
# 4  0016bb22    0

# %% [markdown]
# ## 1.3 Train Data.

# %%
train = pd.read_csv("/kaggle/input/child-mind-institute-problematic-internet-use/train.csv")
train.head()
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
# 2  00105258                    Summer               10                1
# 3  00115b9f                    Winter                9                0
# 4  0016bb22                    Spring               18                1
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
# 2        Fall             71.0            Fall     16.648696             56.5
# 3        Fall             71.0          Summer     18.292347             56.0
# 4      Summer              NaN             NaN           NaN              NaN
#
# ...

# %% [markdown]
# ## 1.4 Test data.

# %%
test = pd.read_csv("/kaggle/input/child-mind-institute-problematic-internet-use/test.csv")
test.head()
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
# 2  00105258                    Summer               10                1
# 3  00115b9f                    Winter                9                0
# 4  0016bb22                    Spring               18                1
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
# 2        Fall             71.0            Fall     16.648696             56.5
# 3        Fall             71.0          Summer     18.292347             56.0
# 4      Summer              NaN             NaN           NaN              NaN
#
# ...

# %% [markdown]
# ## 1.5 Rename for Understanding
#
# **A lifehack:** diving straight into the data can be kind of difficult because you may not really know much about the business. So, renaming all the variables based on your understanding is quite a useful tool to quickly construct your notebook and apply the techniques and ideas you have in mind. Once you develop the "ability" to memorize the dataset through experience, you can revert the names and just work with the usual terminology.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 82 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      3960 non-null   object
#  1   Basic_Demos-Enroll_Season               3960 non-null   object
#  2   Basic_Demos-Age                         3960 non-null   int64
#  3   Basic_Demos-Sex                         3960 non-null   int64
#  4   CGAS-Season                             2555 non-null   object
#  5   CGAS-CGAS_Score                         2421 non-null   float64
#  6   Physical-Season                         3310 non-null   object
#  7   Physical-BMI                            3022 non-null   float64
#  8   Physical-Height                         3027 non-null   float64
#  9   Physical-Weight                         3076 non-null   float64
# ...

# %%
Renamed_train = train.copy()

# Rename columns
Renamed_train.rename(columns={
    'id': 'id',
    'Basic_Demos-Enroll_Season': 'Enrollment_Season',
    'Basic_Demos-Age': 'Age',
    'Basic_Demos-Sex': 'Sex',
    'CGAS-Season': 'Mental_State_Season',
    'CGAS-CGAS_Score': 'Mental_State_Score',
    'Physical-Season': 'Physical_Season',
    'Physical-BMI': 'Body_mass_index',
    'Physical-Height': 'Height',
    'Physical-Weight': 'Weight',
    'Physical-Waist_Circumference': 'Waist_Circumference',
    'Physical-Diastolic_BP': 'Diastolic_Blood_Pressure',
    'Physical-HeartRate': 'Heart_Rate',
    'Physical-Systolic_BP': 'Systolic_Blood_Pressure',
    'Fitness_Endurance-Season': 'Fitness_Endurance_Season',
    'Fitness_Endurance-Max_Stage': 'Max_Stage',
    'Fitness_Endurance-Time_Mins': 'Time_Mins',
    'Fitness_Endurance-Time_Sec': 'Time_Sec',
    'FGC-Season': 'School_fisical_test_Season',
    'FGC-FGC_CU': 'School_fisical_test_abs',
    'FGC-FGC_CU_Zone': 'School_fisical_test_abs_description',
    'FGC-FGC_GSND': 'School_fisical_test_handgrip_non_dominant_hand',
    'FGC-FGC_GSND_Zone': 'School_fisical_test_handgrip_non_dominant_hand_description',
    'FGC-FGC_GSD': 'School_fisical_test_handgrip_dominant_hand',
    'FGC-FGC_GSD_Zone': 'School_fisical_test_handgrip_dominant_hand_description',
    'FGC-FGC_PU': 'School_fisical_test_push_up',
    'FGC-FGC_PU_Zone': 'School_fisical_test_push_up_description',
    'FGC-FGC_SRL': 'School_fisical_test_sit_and_reach_left',
    'FGC-FGC_SRL_Zone': 'School_fisical_test_sit_and_reach_left_description',
    'FGC-FGC_SRR': 'School_fisical_test_sit_and_reach_right',
    'FGC-FGC_SRR_Zone': 'School_fisical_test_sit_and_reach_right_description',
    'FGC-FGC_TL': 'School_fisical_test_trunk_lift',
    'FGC-FGC_TL_Zone': 'School_fisical_test_trunk_lift_description',
    'BIA-Season': 'Stat_biomass_Season',
    'BIA-BIA_Activity_Level_num': 'Stat_biomass_Activity_Level_num',
    'BIA-BIA_BMC': 'Stat_biomass_Bone_Mineral_Content',
    'BIA-BIA_BMI': 'Stat_biomass_Body_Mass_Index',
    'BIA-BIA_BMR': 'Stat_biomass_Basal_Metabolic_Rate',
    'BIA-BIA_DEE': 'Stat_biomass_Daily_Eenergy_Expenditure',
    'BIA-BIA_ECW': 'Stat_biomass_Extracellular_Water',
    'BIA-BIA_FFM': 'Stat_biomass_Fat_Free_Mass',
    'BIA-BIA_FFMI': 'Stat_biomass_Fat_Free_Mass_Index',
    'BIA-BIA_FMI': 'Stat_biomass_Fat_Mass_Index',
    'BIA-BIA_Fat': 'Stat_biomass_Fat_percentage',
    'BIA-BIA_Frame_num': 'Stat_biomass_Body_Frame',
    'BIA-BIA_ICW': 'Stat_biomass_Intracellular_Water',
    'BIA-BIA_LDM': 'Stat_biomass_Lean_Dry_Mass',
    'BIA-BIA_LST': 'Stat_biomass_Lean_Soft_Tissue',
    'BIA-BIA_SMM': 'Stat_biomass_Skeletal_Muscle_Mass',
    'BIA-BIA_TBW': 'Stat_biomass_Total_Body_Water',
    'PAQ_A-Season': 'physical_questionnaire_Adolescent_Season',
    'PAQ_A-PAQ_A_Total': 'physical_questionnaire_Adolescent_Total',
    'PAQ_C-Season': 'physical_questionnaire_Children_Season',
    'PAQ_C-PAQ_C_Total': 'physical_questionnaire_Children_Season',
    'PCIAT-Season': 'Parent_Child_Internet_Addiction_Test_Season',
    'PCIAT-PCIAT_01': 'Parent_Child_Internet_Addiction_Test_Q1',
    'PCIAT-PCIAT_02': 'Parent_Child_Internet_Addiction_Test_Q2',
    'PCIAT-PCIAT_03': 'Parent_Child_Internet_Addiction_Test_Q3',
    'PCIAT-PCIAT_04': 'Parent_Child_Internet_Addiction_Test_Q4',
    'PCIAT-PCIAT_05': 'Parent_Child_Internet_Addiction_Test_Q5',
    'PCIAT-PCIAT_06': 'Parent_Child_Internet_Addiction_Test_Q6',
    'PCIAT-PCIAT_07': 'Parent_Child_Internet_Addiction_Test_Q7',
    'PCIAT-PCIAT_08': 'Parent_Child_Internet_Addiction_Test_Q8',
    'PCIAT-PCIAT_09': 'Parent_Child_Internet_Addiction_Test_Q9',
    'PCIAT-PCIAT_10': 'Parent_Child_Internet_Addiction_Test_Q10',
    'PCIAT-PCIAT_11': 'Parent_Child_Internet_Addiction_Test_Q11',
    'PCIAT-PCIAT_12': 'Parent_Child_Internet_Addiction_Test_Q12',
    'PCIAT-PCIAT_13': 'Parent_Child_Internet_Addiction_Test_Q13',
    'PCIAT-PCIAT_14': 'Parent_Child_Internet_Addiction_Test_Q14',
    'PCIAT-PCIAT_15': 'Parent_Child_Internet_Addiction_Test_Q15',
    'PCIAT-PCIAT_16': 'Parent_Child_Internet_Addiction_Test_Q16',
    'PCIAT-PCIAT_17': 'Parent_Child_Internet_Addiction_Test_Q17',
    'PCIAT-PCIAT_18': 'Parent_Child_Internet_Addiction_Test_Q18',
    'PCIAT-PCIAT_19': 'Parent_Child_Internet_Addiction_Test_Q19',
    'PCIAT-PCIAT_20': 'Parent_Child_Internet_Addiction_Test_Q20',
    'PCIAT-PCIAT_Total': 'Parent_Child_Internet_Addiction_Test_Total',
    'SDS-Season': 'Sleep_Disturbance_Scale_Season',
    'SDS-SDS_Total_Raw': 'Sleep_Disturbance_Scale_Total_Raw_score',
    'SDS-SDS_Total_T': 'Sleep_Disturbance_Scale_Total_T_score',
    'PreInt_EduHx-Season': 'computer_internet_hours_Season',
    'PreInt_EduHx-computerinternet_hoursday': 'computer_internet_hours_per_day',
    'sii': 'Impact_Index'
}, inplace=True)

# %%
Renamed_train
# Out:
#             id Enrollment_Season  Age  Sex Mental_State_Season  \
# 0     00008ff9              Fall    5    0              Winter
# 1     000fd460            Summer    9    0                 NaN
# 2     00105258            Summer   10    1                Fall
# 3     00115b9f            Winter    9    0                Fall
# 4     0016bb22            Spring   18    1              Summer
# ...        ...               ...  ...  ...                 ...
# 3955  ff8a2de4              Fall   13    0              Spring
# 3956  ffa9794a            Winter   10    0                 NaN
# 3957  ffcd4dbd              Fall   11    0              Spring
# 3958  ffed1dd5            Spring   13    0              Spring
# 3959  ffef538e            Spring   11    0                 NaN
#
#       Mental_State_Score Physical_Season  Body_mass_index  Height  Weight  \
# 0                   51.0            Fall        16.877316    46.0    50.8
# ...

# %% [markdown]
# # 2. Understanding "sii".

# %% [markdown]
# ## 2.1 Brief description of "sii"
#
# The host publish this note that indicate our objective.
#
# "Note in particular the field PCIAT-PCIAT_Total. The target sii for this competition is derived from this field as described in the data dictionary: 0 for None, 1 for Mild, 2 for Moderate, and 3 for Severe. Additionally, each participant has been assigned a unique identifier id." - host

# %% [markdown]
# # 3. Feature Eengeniering.

# %% [markdown]
# # 4. Machine Learning.

# %% [markdown]
# # 5. Prediction.

# %% [markdown]
# # 6. Conclusion.
